# %% [markdown]
# ## 连接图数据库

# %%
from py2neo import Graph, Node, Relationship, NodeMatcher

# %%
graph = Graph('http://localhost:7474', auth=('neo4j','12345678'),name='neo4j')

# %%
# t = Node('Person', name='老师')
# a = Node('Person', name='学生A')
# b = Node('Person', name='学生B')

# graph.create(Relationship(t, '师生', a))
# graph.create(Relationship(t, '师生', b))
# graph.create(Relationship(a, '同学', b))

# %%
# 删除所有实体和关系
cypher = 'MATCH (n) DETACH DELETE n'
graph.run(cypher)
# Out:
# (No data)

# %% [markdown]
# ## 从问题中提取实体和关系

# %%
from collections import defaultdict 

dic= defaultdict(list)

def load_data(path, label): 
    for i in open(path, encoding='utf-8'):
        if i.strip() not in dic:
            dic[i.strip()].append(label)
    return dic

#　特征词txt文件路径
disease_path = './build_kg/data/dict/disease.txt'
department_path = './build_kg/data/dict/department.txt'
check_path = './build_kg/data/dict/check.txt'
drug_path = './build_kg/data/dict/drug.txt'
food_path = './build_kg/data/dict/food.txt'
producer_path = './build_kg/data/dict/producer.txt'
symptom_path = './build_kg/data/dict/symptom.txt'
# deny_path = './build_kg/data/dict/deny.txt'

# 加载特征词
disease_wds = load_data(disease_path, 'disease')
department_wds = load_data(department_path, 'department')
check_wds = load_data(check_path, 'check')
drug_wds = load_data(drug_path, 'drug')
food_wds = load_data(food_path, 'food')
producer_wds = load_data(producer_path, 'producer')
symptom_wds = load_data(symptom_path, 'symptom')
# deny_words = load_data(deny_path)

dic
# Out:
# defaultdict(list,
#             {'后发性白内障': ['disease'],
#              '椎体爆裂骨折': ['disease'],
#              '苍耳中毒': ['disease'],
#              '小儿触电与雷击': ['disease'],
#              '颅内高压综合征': ['disease'],
#              '冠状动脉异常起源主动脉': ['disease'],
#              '僵鉧': ['disease'],
#              '腹膜转移癌': ['disease'],
#              '小儿星形细胞瘤': ['disease'],
#              '肢端肥大症': ['disease'],
#              '小儿慢性充血性脾肿大': ['disease'],
#              '脱囊': ['disease'],
#              '先天性喉喘鸣': ['disease'],
#              '脱屑性间质性肺炎': ['disease'],
#              '耻骨结核': ['disease'],
#              '背肌筋膜炎': ['disease'],
#              '髌股关节软骨损伤': ['disease'],
#              '脑脊液漏': ['disease'],
#              '粘液表皮样癌': ['disease'],
#              '中枢神经系统淋巴瘤': ['disease'],
#              '膀胱气痛': ['disease'],
#              '小儿脆性X染色体': ['disease'],
#              '金黄色葡萄球菌肺炎': ['disease'],
#              '急性腐蚀性胃炎': ['disease'],
#              '口腔颌面部皮样、表皮样囊肿': ['disease'],
#              '高弓足': ['disease'],
#              '宫颈外翻': ['disease'],
#              '婴儿及儿童期癫痫及癫痫综合征': ['disease'],
#              '胫前黏液水肿': ['disease'],
#              '小儿严重急性呼吸综合征': ['disease'],
#              '小儿假肥大型肌营养不良': ['disease'],
#              '慢性化脓性鼻窦炎': ['disease'],
#              '耳真菌病': ['disease'],
#              '眼睑皮脂腺癌': ['disease'],
#              '颏下皮样囊肿': ['disease'],
#              '硬脑膜外脓肿': ['disease'],
#              '血劳': ['disease'],
#              '妇科疾病': ['disease'],
#              '小儿轮状病毒性肠炎': ['disease'],
#              '非火器性颅脑开放伤': ['disease'],
#              '无标题文档': ['disease'],
#              '肝内胆管结石': ['disease'],
#              '糖尿病合并低血糖': ['disease'],
#              '营养代谢障碍疾病': ['disease'],
#              '开放性骨折': ['disease'],
#              '肝吸虫病': ['disease'],
#              '特发性心室颤动': ['disease'],
#              '甲状腺癌': ['disease'],
#              '结膜充血': ['disease'],
#              '青光眼睫状体炎综合征': ['disease'],
#              '窦性心动过速': ['disease'],
#              '眼内异物': ['disease'],
#              '胃型哮喘': ['disease'],
#              '先天性巨输尿管': ['disease'],
#              '奥迪括约肌功能异常': ['disease'],
#              '食物变应性和不耐受性': ['disease'],
#              '胃切除后胆汁返流性胃炎': ['disease'],
#              '小儿血管瘤血小板减少综合征': ['disease'],
#              '小儿维生素D缺乏性手足搐搦症': ['disease'],
#              '无症状性脑梗死': ['disease'],
#              '卵巢颗粒细胞瘤': ['disease'],
#              '女性性早熟': ['disease'],
#              '念珠菌性包皮龟头炎-测试': ['disease'],
#              '溢泪症': ['disease'],
#              '柞蚕蛹脑病': ['disease'],
#              '瘰疬性皮肤结核病': ['disease'],
#              '桡骨小头骨骺分离': ['disease'],
#              '桡骨骨折': ['disease'],
#              '二尖瓣闭锁不全': ['disease'],
#              '结核性宫颈炎': ['disease'],
#              '哮喘': ['disease'],
#              '矫正型大动脉错位': ['disease'],
#              '嗜酸性细胞增多症': ['disease'],
#              '眼眶脓肿': ['disease'],
#              '哕': ['disease'],
#              '淋巴结结节病': ['disease'],
#              '新生儿出血症': ['disease'],
#              '臂丛神经痛': ['disease'],
#              '半月线疝': ['disease'],
#              '鼻病': ['disease'],
#              '多囊肾': ['disease'],
#              '外伤性脑脊液漏': ['disease'],
#              '鼠疫耶尔森菌肺炎': ['disease'],
#              '小儿甲状腺癌': ['disease'],
#              '结核性角膜病变': ['disease'],
#              '新生儿锁骨骨折': ['disease'],
#              '特发性含铁血黄素沉着症': ['disease'],
#              '慢性进行性舞蹈病': ['disease'],
#              '高钙血症肾病': ['disease'],
#              '视网膜下新生血管膜': ['disease'],
#              '急性腮腺炎性睾丸炎': ['disease'],
#              '颅咽管瘤': ['disease'],
#              '蜘蛛痣': ['disease'],
#              '气管梗阻': ['disease'],
#              '海胆刺伤及海胆肉芽肿': ['disease'],
#              '革兰阳性球菌和革兰阴性杆菌性巩膜炎': ['disease'],
#              'c胰岛功能性β细胞瘤': ['disease'],
#              '网膜扭转': ['disease'],
#              '强直型脑瘫': ['disease'],
#              '老年人肺性脑病': ['disease'],
#              '钩虫性十二指肠炎综合征': ['disease'],
#              '牙体缺损': ['disease'],
#              '短暂性脑缺血发作': ['disease'],
#              '心脏病': ['disease'],
#              '间歇性斜视': ['disease'],
#              '心房心肌梗死': ['disease'],
#              '小儿肝豆状核变性': ['disease'],
#              '气管及支气管发育障碍': ['disease'],
#              '老年休克': ['disease'],
#              '阴囊丝虫病': ['disease'],
#              '血管内皮瘤': ['disease'],
#              '多形性脂肪瘤': ['disease'],
#              '肤胀': ['disease'],
#              '颅底凹陷症': ['disease'],
#              '胞内分枝杆菌感染': ['disease'],
#              '鲜红斑痣': ['disease'],
#              '猝死': ['disease'],
#              '大隐静脉曲张': ['disease'],
#              '异色性虹膜睫状体炎': ['disease'],
#              '左心发育不良': ['disease'],
#              '新生儿弥散性血管内凝血': ['disease'],
#              '白屑风': ['disease'],
#              '胰岛细胞类癌': ['disease'],
#              '皮肤病': ['disease'],
#              '卵黄状黄斑营养不良': ['disease'],
#              '慢性脓胸': ['disease'],
#              '食管囊肿': ['disease'],
#              '视网膜色素上皮炎': ['disease'],
#              '腺样体肥大': ['disease'],
#              '电脑病': ['disease'],
#              '高渗性脱水': ['disease'],
#              '伤寒与副伤寒': ['disease'],
#              '呼吸道合胞病毒肺炎': ['disease'],
#              '小儿急性胰腺炎': ['disease'],
#              '羊胡疮': ['disease'],
#              '吩噻嗪类抗精神病药物中毒': ['disease'],
#              '心理障碍': ['disease'],
#              '痢疾': ['disease'],
#              '肺结核': ['disease'],
#              '手足徐动性脑瘫': ['disease'],
#              '先天性巨结肠': ['disease'],
#              '神经性头痛': ['disease'],
#              '症状性癫痫综合征': ['disease'],
#              '双分支阻滞': ['disease'],
#              '化学液体吸入': ['disease'],
#              '营养缺乏性神经病变': ['disease'],
#              '小儿真菌性肺炎': ['disease'],
#              '肠道血管畸形': ['disease'],
#              '情感障碍': ['disease'],
#              '食管梅毒': ['disease'],
#              '老年人吸入性肺炎': ['disease'],
#              '流行性感冒': ['disease'],
#              '羊水栓塞': ['disease'],
#              '迷路窗破裂': ['disease'],
#              '心瘅': ['disease'],
#              '炭疽病': ['disease'],
#              '血气胸': ['disease'],
#              '肩胛上神经卡压症': ['disease'],
#              '结核性干性胸膜炎': ['disease'],
#              '糖原贮积病': ['disease'],
#              '胞痹': ['disease'],
#              '食管憩室': ['disease'],
#              '产后痉症': ['disease'],
#              '拉沙热': ['disease'],
#              '尿毒症昏迷': ['disease'],
#              '并发截瘫的脊柱结核': ['disease'],
#              '大骨节病': ['disease'],
#              '卡波西肉瘤': ['disease'],
#              '药物性牙龈增生': ['disease'],
#              '淋病合并症精囊炎': ['disease'],
#              '坐板疮': ['disease'],
#              '心房内折返性心动过速': ['disease'],
#              '化脓性耳廓软骨膜炎': ['disease'],
#              '汗孔角化病': ['disease'],
#              '妊娠期肝血肿及破裂': ['disease'],
#              '老年人急性左心衰竭': ['disease'],
#              '萎缩性咽炎': ['disease'],
#              '异位性皮炎': ['disease'],
#              '金属引起的口腔黏膜疾病': ['disease'],
#              '眼眶淋巴管瘤': ['disease'],
#              '高脂蛋白血症Ⅳ型': ['disease'],
#              '神经纤维瘤病': ['disease'],
#              '原位癌': ['disease'],
#              '嗜睡症': ['disease'],
#              '荨麻疹型药疹': ['disease'],
#              '小儿霉甘蔗中毒': ['disease'],
#              '梅毒性关节炎': ['disease'],
#              '婴儿期短暂性低丙球蛋白血症': ['disease'],
#              '失眠': ['disease'],
#              '肺吸虫病': ['disease'],
#              '小儿心搏呼吸骤停与心肺复苏术': ['disease'],
#              '噤口痢': ['disease'],
#              '眶下间隙感染': ['disease'],
#              '腹壁坏死性筋膜炎': ['disease'],
#              '胎膜早破': ['disease'],
#              '淋巴细胞脉络丛脑膜炎': ['disease'],
#              '小儿血管瘤': ['disease'],
#              '老年人室性心动过速': ['disease'],
#              '伸指肌腱损伤': ['disease'],
#              '老年人过敏性紫癜': ['disease'],
#              '阴道黑色素瘤': ['disease'],
#              '外伤性脾破裂': ['disease'],
#              '小儿维生素B2缺乏病': ['disease'],
#              '阿斯匹林不耐受三联症': ['disease'],
#              '颌骨囊肿': ['disease'],
#              '汗管棘皮瘤': ['disease'],
#              '脑膜肉瘤': ['disease'],
#              '附件炎': ['disease'],
#              '咽鼓管异常开放症': ['disease'],
#              '前列腺囊肿': ['disease'],
#              '斜颈': ['disease'],
#              '类鼻疽': ['disease'],
#              '金黄色葡萄球菌性边缘性角膜炎': ['disease'],
#              '小儿肾积水': ['disease'],
#              '巨细胞动脉炎和风湿性多肌痛': ['disease'],
#              '电灼伤': ['disease'],
#              '急性细支气管炎': ['disease'],
#              '脐尿管囊肿及脐尿管瘘': ['disease'],
#              '脏躁': ['disease'],
#              '血卟啉病': ['disease'],
#              '小儿骨与关节结核': ['disease'],
#              '痉挛性脑瘫': ['disease'],
#              '热衰竭': ['disease'],
#              '特发性面神经瘫痪': ['disease'],
#              '干眼': ['disease'],
#              '小儿流感病毒肺炎': ['disease'],
#              '血管内大B细胞淋巴瘤': ['disease'],
#              '肾硬化症': ['disease'],
#              '脉络膜裂伤': ['disease'],
#              '胆脂瘤型中耳炎': ['disease'],
#              '膀胱瘘': ['disease'],
#              '麻风性周围神经病': ['disease'],
#              '盆腔肿瘤': ['disease'],
#              '先天性梅毒性肝硬化': ['disease'],
#              '睾丸损伤': ['disease'],
#              '胸壁软组织损伤': ['disease'],
#              '骨筋膜室综合症': ['disease'],
#              '营养不良性皮肤钙化病': ['disease'],
#              '食道溃疡': ['disease'],
#              '尿毒症性心包炎': ['disease'],
#              '睾丸肿瘤': ['disease'],
#              '血栓性血小板减少性紫癜': ['disease'],
#              '小儿单纯性血尿': ['disease'],
#              '局灶性肾小球硬化症': ['disease'],
#              '脑室内出血': ['disease'],
#              '颅裂': ['disease'],
#              '结核性苔藓': ['disease'],
#              '粪类圆线虫病': ['disease'],
#              '新生儿肝脾肿大': ['disease'],
#              '着色芽生菌病': ['disease'],
#              '原发性硬化性胆管炎': ['disease'],
#              '小肠血管瘤': ['disease'],
#              '小儿红白血病': ['disease'],
#              '慢性乳头状溃疡性脓皮病': ['disease'],
#              '小儿肺动脉高压': ['disease'],
#              '猫抓病': ['disease'],
#              '眼睑炭疽': ['disease'],
#              '颅内脂肪瘤': ['disease'],
#              '新生儿呼吸窘迫综合征': ['disease'],
#              '眶脑膜瘤': ['disease'],
#              '法洛四联症': ['disease'],
#              '胰腺囊肿': ['disease'],
#              '农民肺': ['disease'],
#              '乙状窦血栓性静脉炎': ['disease'],
#              '硬脊膜外脓肿': ['disease'],
#              '痛风': ['disease'],
#              '强直性脊柱炎性巩膜炎': ['disease'],
#              '工业毒物中毒性周围神经病': ['disease'],
#              '福克斯-阜太斯病': ['disease'],
#              '睑皮松垂症': ['disease'],
#              '弥漫性掌跖角化病': ['disease'],
#              '先天性跖骨内收畸形': ['disease'],
#              '原发性下肢静脉瓣膜关闭不全': ['disease'],
#              '尿道憩室': ['disease'],
#              '类丹毒': ['disease'],
#              '外伤后颅内积气': ['disease'],
#              '颅内转移瘤': ['disease'],
#              '尿道结核': ['disease'],
#              '胃肠疾病': ['disease'],
#              '甲亢性心脏病': ['disease'],
#              '婴儿痉挛症': ['disease'],
#              '卵泡发育不良': ['disease'],
#              '小儿脑水肿与颅内高压综合征': ['disease'],
#              '开放性手外伤': ['disease'],
#              '软骨母细胞瘤': ['disease'],
#              '拔毛狂': ['disease'],
#              '布氏菌病': ['disease'],
#              '小儿慢性胰腺炎': ['disease'],
#              '色素性青光眼': ['disease'],
#              '软组织肿瘤': ['disease'],
#              '原发性混合型冷球蛋白血症性血管炎': ['disease'],
#              '紫绀-杵状指-肝病综合征': ['disease'],
#              '选择性IgA缺乏症': ['disease'],
#              '突发性聋': ['disease'],
#              '房事头疼症': ['disease'],
#              '食管炎': ['disease'],
#              '泪道阻塞': ['disease'],
#              '剥脱综合征': ['disease'],
#              '阴冷': ['disease'],
#              '老年人前列腺增生症': ['disease'],
#              '剥脱性皮炎': ['disease'],
#              '自身免疫性甲状腺疾病相关肾病': ['disease'],
#              '卓－艾氏综合征': ['disease'],
#              '珍珠丘疹': ['disease'],
#              '妊娠合并多囊肾': ['disease'],
#              '窦性期前收缩': ['disease'],
#              '肺棘球蚴病': ['disease'],
#              '小儿甲基丙二酸血症': ['disease'],
#              '遗传性纤维蛋白原缺乏症': ['disease'],
#              '跟骨骨折': ['disease'],
#              '舌静脉曲张': ['disease'],
#              '溃疡性皮肤结核': ['disease'],
#              '老年人甲亢性心脏病': ['disease'],
#              '幼年性透明纤维瘤病': ['disease'],
#              '夏伊-德雷格综合征': ['disease'],
#              '巨吻棘头虫病': ['disease'],
#              '蝶骨嵴脑膜瘤': ['disease'],
#              '妊娠合并消化性溃疡': ['disease'],
#              '消化性溃疡': ['disease'],
#              '烧伤休克': ['disease'],
#              '非典型纤维黄色瘤': ['disease'],
#              '小儿衣原体肺炎': ['disease'],
#              '梨状肌症候群': ['disease'],
#              '脆弱性骨硬化': ['disease'],
#              '小儿脊髓前动脉综合征': ['disease'],
#              '小儿淀粉样变性病': ['disease'],
#              '家族性渗出性玻璃体视网膜病变': ['disease'],
#              '胬肉攀睛': ['disease'],
#              '小儿癫痫发作诱发失语综合征': ['disease'],
#              '绝经期尿路感染': ['disease'],
#              '老年人风湿性心脏病': ['disease'],
#              '阿米巴肝脓肿': ['disease'],
#              '心脏乳头样弹性纤维瘤': ['disease'],
#              '小儿溶血性贫血': ['disease'],
#              '角膜鳞状细胞癌': ['disease'],
#              '胃真菌病': ['disease'],
#              '斯蒂尔病': ['disease'],
#              '蜈蚣蜇伤': ['disease'],
#              '发育迟缓': ['disease'],
#              '小儿加压素分泌过多综合征': ['disease'],
#              '闭经': ['disease'],
#              '阴虚发热': ['disease'],
#              '子悬': ['disease'],
#              '偏头痛': ['disease'],
#              '老年人帕金森病': ['disease'],
#              '目劄病': ['disease'],
#              '出血性输卵管炎': ['disease'],
#              '肾及输尿管重复畸形': ['disease'],
#              '乙胺嘧啶中毒': ['disease'],
#              '食管过短': ['disease'],
#              '未分化结缔组织病': ['disease'],
#              '冲浪者结节': ['disease'],
#              '新生儿呕吐': ['disease'],
#              '小儿卡肺囊虫肺炎': ['disease'],
#              '体寒': ['disease'],
#              '雷诺氏病': ['disease'],
#              '镍皮炎': ['disease'],
#              '先天性十二指肠闭锁': ['disease'],
#              '拇囊炎': ['disease'],
#              '大网膜扭转': ['disease'],
#              'Ⅰ型免疫母细胞性淋巴腺病': ['disease'],
#              '外阴腺泡状软组织肉瘤': ['disease'],
#              '产力异常性难产': ['disease'],
#              '无机碱皮肤损伤': ['disease'],
#              '半椎体畸形': ['disease'],
#              '中老年男子部分性雄激素缺乏综合征': ['disease'],
#              '外向孤独症': ['disease'],
#              '下呼吸道感染': ['disease'],
#              '假性醛固酮减少症': ['disease'],
#              '镍中毒': ['disease'],
#              '脑垂体腺瘤': ['disease'],
#              '男性病': ['disease'],
#              '肘内翻畸形': ['disease'],
#              '气瘿': ['disease'],
#              '老年人黏液性瓣膜病': ['disease'],
#              '风秘': ['disease'],
#              '小儿紫斑湿疹综合征': ['disease'],
#              '月骨脱位': ['disease'],
#              '药物中毒': ['disease'],
#              '筋瘤': ['disease'],
#              '血管神经性水肿': ['disease'],
#              '羊膜带综合征': ['disease'],
#              '萎缩纹': ['disease'],
#              '胸骨骨髓炎': ['disease'],
#              '大肠湿热': ['disease'],
#              '水过多': ['disease'],
#              '蜂螫伤': ['disease'],
#              '食瘕': ['disease'],
#              '先天性主动脉弓畸形': ['disease'],
#              '小儿动力性肠梗阻': ['disease'],
#              '腱病': ['disease'],
#              '腺样囊性癌': ['disease'],
#              '巨人症与肢端肥大症': ['disease'],
#              '老年斑': ['disease'],
#              '外阴血管外皮细胞瘤': ['disease'],
#              '小脑扁桃体下疝畸形': ['disease'],
#              '月经性哮喘': ['disease'],
#              '良性高血压性小动脉性肾硬化': ['disease'],
#              '牙周萎缩': ['disease'],
#              '鼻中隔脓肿': ['disease'],
#              '臁疮': ['disease'],
#              '肩关节周围炎': ['disease'],
#              '糖尿病酮症酸中毒': ['disease'],
#              '喉刺伤': ['disease'],
#              '肺动脉瓣关闭不全': ['disease'],
#              '卵巢无性细胞瘤': ['disease'],
#              '早泄': ['disease'],
#              '尿道缺如及先天性尿道闭锁': ['disease'],
#              '睾丸女性化': ['disease'],
#              '结节性硬化': ['disease'],
#              '维生素K缺乏病': ['disease'],
#              '尘螨过敏性哮喘': ['disease'],
#              '肠气肿综合征': ['disease'],
#              '弓形体病性巩膜炎': ['disease'],
#              '小儿雄激素不敏感综合征': ['disease'],
#              '坏死性肠炎': ['disease'],
#              '软骨黏液样纤维瘤': ['disease'],
#              '老年人乳头肌功能不全和断裂': ['disease'],
#              '卵巢纤维组织来源肿瘤': ['disease'],
#              '脑垂体功能异常伴发的精神障碍': ['disease'],
#              '霰粒肿': ['disease'],
#              '羰基镍中毒': ['disease'],
#              '贾第虫病': ['disease'],
#              '免疫抑制药和抗癌药中毒性肾病': ['disease'],
#              '久疟': ['disease'],
#              '高度房室传导阻滞': ['disease'],
#              '子宫纵隔': ['disease'],
#              '蜂窝织炎': ['disease'],
#              '腕枪刺状畸形': ['disease'],
#              '子宫内翻': ['disease'],
#              '瘀证': ['disease'],
#              '小儿急性中毒性脑病': ['disease'],
#              '小儿肥胖症': ['disease'],
#              '稻农皮炎': ['disease'],
#              '急性肠炎': ['disease'],
#              '遗传性补体缺陷病': ['disease'],
#              '隐睾': ['disease'],
#              '躯体疾病伴发的精神障碍': ['disease'],
#              '绝经': ['disease'],
#              '蓝痣': ['disease'],
#              '副银屑病': ['disease'],
#              '异染性脑白质营养不良': ['disease'],
#              '布氏杆菌性关节炎': ['disease'],
#              '小儿糖原贮积病Ⅴ型': ['disease'],
#              '实喘': ['disease'],
#              '先天性动脉导管未闭': ['disease'],
#              '坏疽性脓皮症': ['disease'],
#              '泪腺炎': ['disease'],
#              '复发性无菌性脑膜炎': ['disease'],
#              '脊柱骨折': ['disease'],
#              '电解质紊乱': ['disease'],
#              '产后出血': ['disease'],
#              '咽白喉': ['disease'],
#              '急性卵巢、输卵管自身扭转': ['disease'],
#              '新生儿皮下坏疽': ['disease'],
#              '房性期前收缩': ['disease'],
#              '新生儿心律失常': ['disease'],
#              '小儿尿道下裂': ['disease'],
#              '小儿急性阑尾炎': ['disease'],
#              '内分泌病': ['disease'],
#              '疱疹样皮炎': ['disease'],
#              '妊娠合并甲状旁腺功能亢进': ['disease'],
#              '输卵管性不孕': ['disease'],
#              '动脉栓塞': ['disease'],
#              '肾性糖尿': ['disease'],
#              '听神经鞘瘤': ['disease'],
#              '柯莱斯骨折': ['disease'],
#              '黏多糖贮积症': ['disease'],
#              '常现丝虫病': ['disease'],
#              '小儿肠病性肢端皮炎': ['disease'],
#              '小儿先天性主动脉瓣狭窄': ['disease'],
#              '肺错构瘤': ['disease'],
#              '智力低下': ['disease'],
#              '踝关节结核': ['disease'],
#              '足跟瘀斑': ['disease'],
#              '小叶增生': ['disease'],
#              '卵巢病': ['disease'],
#              '酒精性肝病': ['disease'],
#              '淀粉样变病的胃肠道表现': ['disease'],
#              '肺嗜酸性粒细胞浸润症': ['disease'],
#              '狼疮性肾炎': ['disease'],
#              '二水焦磷酸钙结晶沉积症': ['disease'],
#              '新生儿急性肾功能衰竭': ['disease'],
#              '脊髓蛛网膜炎': ['disease'],
#              '慢性干燥性鼻炎': ['disease'],
#              '结胸证': ['disease'],
#              '噪声性聋': ['disease'],
#              '新生儿侵袭性大肠杆菌肠炎': ['disease'],
#              '胰腺癌': ['disease'],
#              'Pasini-Pierni进行性皮肤萎缩': ['disease'],
#              '三环类抗忧郁药中毒': ['disease'],
#              '肠病原性大肠埃希杆菌感染': ['disease'],
#              '职业病': ['disease'],
#              '阿米巴性阴道炎': ['disease'],
#              '血色病性骨关节病': ['disease'],
#              '黑头粉刺痣': ['disease'],
#              '结肠类癌': ['disease'],
#              '过敏性湿疹': ['disease'],
#              '原发性腹膜炎': ['disease'],
#              '血管球瘤': ['disease'],
#              '暴痢': ['disease'],
#              '硬肿症': ['disease'],
#              '皮肤B细胞淋巴样结节型增生': ['disease'],
#              '血清病和血清病样反应': ['disease'],
#              '皮肤蝇蛆病': ['disease'],
#              '神经鞘黏液瘤': ['disease'],
#              '咳嗽': ['disease'],
#              '小儿结节病': ['disease'],
#              '脓胸': ['disease'],
#              '小儿阵发性心动过速': ['disease'],
#              '乙脑伴发的精神障碍': ['disease'],
#              '混合型肾小管性酸中毒': ['disease'],
#              '重瞳': ['disease'],
#              '甲亢': ['disease'],
#              '线粒体病': ['disease'],
#              '肠侵袭性大肠埃希杆菌感染': ['disease'],
#              '贝壳甲综合征': ['disease'],
#              '恶性小汗腺螺旋腺瘤': ['disease'],
#              '脊椎结核寒性脓肿穿入空腔脏器': ['disease'],
#              '小儿过敏性支气管炎': ['disease'],
#              '致命性中线肉芽肿': ['disease'],
#              '老年人慢性支气管炎': ['disease'],
#              '口腔炎': ['disease'],
#              '转移性小肠肿瘤': ['disease'],
#              '过敏性肉芽肿性血管炎相关巩膜炎': ['disease'],
#              'α1-抗胰蛋白酶缺乏性脂膜炎': ['disease'],
#              '外阴尤因肉瘤': ['disease'],
#              '感染性疾病所致贫血': ['disease'],
#              '气压伤': ['disease'],
#              '轮状病毒性肠炎': ['disease'],
#              '宫颈癌前病变': ['disease'],
#              '光感型药疹': ['disease'],
#              '小儿高磷酸酶血症': ['disease'],
#              '锥虫病': ['disease'],
#              '迟发性外伤性脑内血肿': ['disease'],
#              '小儿继发性腹膜炎': ['disease'],
#              '婴儿肢端脓皮病': ['disease'],
#              '花翳自陷': ['disease'],
#              '乳头侵蚀性腺瘤病': ['disease'],
#              '小儿基底细胞痣综合征': ['disease'],
#              '前列腺脓肿': ['disease'],
#              '病毒性脑膜炎': ['disease'],
#              '女性尿道癌': ['disease'],
#              '慢性淋巴结炎': ['disease'],
#              '猛兽伤': ['disease'],
#              '胸腺小细胞癌': ['disease'],
#              '槭糖尿病': ['disease'],
#              '细粒棘球蚴病': ['disease'],
#              '蕈样真菌病和Sezary综合征': ['disease'],
#              '小儿砷中毒': ['disease'],
#              '混合结缔组织病': ['disease'],
#              '单侧关节突关节脱位': ['disease'],
#              '尿失禁': ['disease'],
#              '隐匿型冠状动脉粥样硬化性心脏病': ['disease'],
#              '风疹': ['disease'],
#              '胃潴留': ['disease'],
#              '睾丸炎': ['disease'],
#              '登革出血热': ['disease'],
#              '碱性磷酸钙结晶沉积病': ['disease'],
#              '劳力性心绞痛': ['disease'],
#              '乳腺导管瘤': ['disease'],
#              '慢性结肠炎': ['disease'],
#              '女劳疸': ['disease'],
#              '深海恐惧症': ['disease'],
#              '小儿牙本质生长不全综合征': ['disease'],
#              '先天性前尿道瓣膜': ['disease'],
#              '腹腔干动脉瘤': ['disease'],
#              '角膜病': ['disease'],
#              '小儿病毒感染性口炎': ['disease'],
#              '毛囊性鱼鳞病': ['disease'],
#              '小儿埃莱尔-当洛综合征': ['disease'],
#              '主动脉瓣闭锁不全': ['disease'],
#              '跟痛症': ['disease'],
#              '高血压性心肌病': ['disease'],
#              '贲门失弛缓症': ['disease'],
#              '脊髓血管病': ['disease'],
#              '大叶性肺炎': ['disease'],
#              '单次发作抑郁症': ['disease'],
#              '小儿贲门失弛缓症': ['disease'],
#              '小儿神经皮肤综合征': ['disease'],
#              '结肠血管扩张症': ['disease'],
#              '维生素D缺乏病': ['disease'],
#              '囊痈': ['disease'],
#              '干酪性鼻炎': ['disease'],
#              'A链球菌群感染': ['disease'],
#              '口腔颌面部毛细管型淋巴管瘤': ['disease'],
#              '旅行者腹泻': ['disease'],
#              '浓缩胆汁综合征': ['disease'],
#              'Kaposis肉瘤': ['disease'],
#              '指骨骨折': ['disease'],
#              '老年人重症肌无力': ['disease'],
#              '渗出性多形红斑': ['disease'],
#              '前骨间神经卡压综合征': ['disease'],
#              '肺泡微结石症': ['disease'],
#              '小儿颅内出血': ['disease'],
#              '玻璃体液化': ['disease'],
#              '视神经乳头水肿及视盘水肿': ['disease'],
#              '煤气中毒': ['disease'],
#              '胫后神经损伤': ['disease'],
#              '婴儿骨皮质增生症': ['disease'],
#              '戈登综合征': ['disease'],
#              '胆道结石': ['disease'],
#              '外阴大汗腺瘤': ['disease'],
#              '小儿维生素D缺乏性佝偻病': ['disease'],
#              '先天性全丙种球蛋白低下血症': ['disease'],
#              '小儿猪带绦虫病和囊虫病': ['disease'],
#              '帕金森病性痴呆': ['disease'],
#              '早孕': ['disease'],
#              '老年人大肠肿瘤': ['disease'],
#              '汗孔周围炎及多发性汗腺脓肿': ['disease'],
#              '小儿神经白塞综合征': ['disease'],
#              '脑性瘫痪': ['disease'],
#              '肺性脑病': ['disease'],
#              '慢性腹泻': ['disease'],
#              '妊娠瘙痒性荨麻疹性丘疹及斑块病': ['disease'],
#              '粟疮': ['disease'],
#              '痃癖': ['disease'],
#              '桡骨颈骨折和桡骨头骨骺分离': ['disease'],
#              '胸痹心痛': ['disease'],
#              '先天性高肩胛症': ['disease'],
#              '扁平苔癣': ['disease'],
#              '老年人腹主动脉瘤': ['disease'],
#              '网络成瘾': ['disease'],
#              '痒性紫癜': ['disease'],
#              '淋巴管平滑肌瘤': ['disease'],
#              '毛囊脓疱病': ['disease'],
#              '小儿嗜血流感杆菌肺炎': ['disease'],
#              '遗传性凝血因子Ⅹ缺乏': ['disease'],
#              '白细胞葡萄糖-6-磷酸脱氢酶缺乏症': ['disease'],
#              '结节性脂膜炎': ['disease'],
#              '霍奇金病': ['disease'],
#              '溶血性贫血': ['disease'],
#              '耳石症': ['disease'],
#              '低氯性碱中毒': ['disease'],
#              '椎体骨软骨病': ['disease'],
#              '兰伯特-伊顿综合征': ['disease'],
#              '隐匿型乳腺癌': ['disease'],
#              '肝气不舒': ['disease'],
#              '恶性青光眼': ['disease'],
#              '口腔扁平苔藓': ['disease'],
#              '射精功能障碍': ['disease'],
#              '宾斯旺格病': ['disease'],
#              '十二指肠重复畸形': ['disease'],
#              '内生性软骨瘤': ['disease'],
#              '先天性小喉': ['disease'],
#              '白淫': ['disease'],
#              '小儿先天性肝囊肿': ['disease'],
#              '小儿睾丸扭转': ['disease'],
#              '视网膜后膜': ['disease'],
#              '小儿心房扑动': ['disease'],
#              '原发性醛固酮增多症': ['disease'],
#              '骨坏死': ['disease'],
#              '眼眶脑膜瘤': ['disease'],
#              '荚膜组织胞浆菌病': ['disease'],
#              '新生儿单纯疱疹病毒感染': ['disease'],
#              '产褥期乳腺炎': ['disease'],
#              '滑膜炎': ['disease'],
#              '过劳肥': ['disease'],
#              '乳头状囊腺癌': ['disease'],
#              '脉络膜转移癌': ['disease'],
#              '肺大疱': ['disease'],
#              '药物过敏性口炎': ['disease'],
#              '老年人糖尿病乳酸性中毒': ['disease'],
#              '腹主动脉血栓形成综合征': ['disease'],
#              '肺淀粉样变性': ['disease'],
#              '喉肿瘤': ['disease'],
#              '疟疾肾病': ['disease'],
#              '新生儿失血性贫血': ['disease'],
#              '咽炎': ['disease'],
#              '乳头状汗腺腺瘤': ['disease'],
#              '慢性劳损性颈背部筋膜纤维织炎': ['disease'],
#              '脊柱结核': ['disease'],
#              '卵巢囊肿': ['disease'],
#              '胸椎骨折': ['disease'],
#              '十二指肠胃反流及胆汁反流性胃炎': ['disease'],
#              '小儿球形细胞脑白质营养不良': ['disease'],
#              '全身性红斑狼疮': ['disease'],
#              '胸主动脉瘤': ['disease'],
#              '小儿人类细小病毒B19感染': ['disease'],
#              '牙龈癌': ['disease'],
#              '吉尔伯特综合征': ['disease'],
#              '儿童口吃': ['disease'],
#              '外耳道耵聍腺肿瘤': ['disease'],
#              '眼眶炎性假瘤': ['disease'],
#              '原发性高脂蛋白血症与黄瘤增生病': ['disease'],
#              '颈肩痛': ['disease'],
#              '颈椎后脱位': ['disease'],
#              '脑膨出和脑脊膜膨出': ['disease'],
#              '脓肿': ['disease'],
#              '妊娠恶阻': ['disease'],
#              '小儿潮红综合征': ['disease'],
#              '小儿狂犬病': ['disease'],
#              '小儿肠系膜淋巴结结核': ['disease'],
#              '视盘炎': ['disease'],
#              '瑞列绦虫病': ['disease'],
#              '先天性感觉性神经病': ['disease'],
#              '黄斑裂孔': ['disease'],
#              '小儿肾性尿崩症': ['disease'],
#              '老年人尿失禁': ['disease'],
#              '输卵管结核': ['disease'],
#              '神经性耳鸣': ['disease'],
#              '全植物神经功能不全': ['disease'],
#              '创伤性窒息': ['disease'],
#              '近端(Ⅱ型)肾小管性酸中毒': ['disease'],
#              '抬头纹': ['disease'],
#              '坐骨直肠窝脓肿': ['disease'],
#              '跟腱断裂': ['disease'],
#              '眼眶脂肪瘤': ['disease'],
#              '急性粒细胞性白血病': ['disease'],
#              '噎膈': ['disease'],
#              '裂纹舌': ['disease'],
#              '包涵体肌炎': ['disease'],
#              'A-V综合征': ['disease'],
#              '先天性脑积水': ['disease'],
#              '肱骨髁上骨折': ['disease'],
#              '房室结折返性心动过速': ['disease'],
#              '阴茎头包皮炎': ['disease'],
#              '上皮样囊肿': ['disease'],
#              '非闭塞性肠系膜血管缺血': ['disease'],
#              '小儿情感交叉擦腿综合征': ['disease'],
#              '高温引起的溶血性贫血': ['disease'],
#              '前置胎盘': ['disease'],
#              '过敏性支气管肺曲霉病': ['disease'],
#              '肾上腺囊肿': ['disease'],
#              '小儿军团病': ['disease'],
#              '不动纤毛综合征': ['disease'],
#              '痰积': ['disease'],
#              '后天性三尖瓣关闭不全': ['disease'],
#              '老年期谵妄': ['disease'],
#              '变应性皮肤结节性血管炎': ['disease'],
#              '小儿自律性房性心动过速': ['disease'],
#              '外阴皮肤脂溢性皮炎': ['disease'],
#              '前庭大腺癌': ['disease'],
#              '眼眶内海绵状血管瘤': ['disease'],
#              '丹吉尔病': ['disease'],
#              '球后视神经炎': ['disease'],
#              '神经衰弱': ['disease'],
#              '恶性血管内皮细胞瘤': ['disease'],
#              '头皮痣': ['disease'],
#              '脉络丛乳头状瘤': ['disease'],
#              '无症状型心肌缺血': ['disease'],
#              '甲型H1N1流感': ['disease'],
#              '淋巴丝虫病': ['disease'],
#              '鼻前庭囊肿': ['disease'],
#              '亚临床甲状腺功能亢进': ['disease'],
#              '小儿帕套综合征': ['disease'],
#              '绝经与阿尔茨海默病综合征': ['disease'],
#              '小儿外源性变应性肺泡炎': ['disease'],
#              '肺动脉口狭窄': ['disease'],
#              '小儿播散性血管内凝血': ['disease'],
#              '重症肌无力危象': ['disease'],
#              '肝硬化': ['disease'],
#              '物理性变应性': ['disease'],
#              '胸主动脉夹层动脉瘤': ['disease'],
#              '老年人肥胖症': ['disease'],
#              '浸润型肺结核': ['disease'],
#              '下丘脑疾病': ['disease'],
#              '小儿高血压': ['disease'],
#              '赖利-戴综合征': ['disease'],
#              '错构瘤': ['disease'],
#              '单纯性脊柱结核': ['disease'],
#              '成人多动症': ['disease'],
#              '男性青春期乳房发育': ['disease'],
#              '传染性单核细胞增多': ['disease'],
#              '尿路真菌感染': ['disease'],
#              '佩梅病': ['disease'],
#              '维生素Ａ缺乏症所致的角膜溃疡病': ['disease'],
#              '小儿肝炎再生障碍性贫血综合征': ['disease'],
#              '陈旧性肺结核': ['disease'],
#              '婴儿痤疮': ['disease'],
#              '慢性胰腺炎': ['disease'],
#              '老年人结核性脑膜炎': ['disease'],
#              '暴露性角膜炎': ['disease'],
#              '涎腺囊肿': ['disease'],
#              '脊髓出血性疾病': ['disease'],
#              '蔓状血管瘤': ['disease'],
#              '先天性巨尿道症': ['disease'],
#              '白内障': ['disease'],
#              '胎死宫内': ['disease'],
#              '脱屑性红皮病': ['disease'],
#              '牙周炎': ['disease'],
#              '肝胆湿热': ['disease'],
#              '老年人高钙血症': ['disease'],
#              '单发性毛鞘瘤': ['disease'],
#              '蚂蚁叮咬': ['disease'],
#              '扁桃体结石': ['disease'],
#              '非结核分枝杆菌性角膜炎': ['disease'],
#              '亚硝酸盐中毒': ['disease'],
#              '脑挫裂伤': ['disease'],
#              '外层渗出性视网膜病变': ['disease'],
#              '脊神经根炎': ['disease'],
#              '老年人上腔静脉受压综合征': ['disease'],
#              '肝风内动证': ['disease'],
#              '肺病': ['disease'],
#              '高脂蛋白血症Ⅴ型': ['disease'],
#              '继发性皮肤CD30阳性大细胞淋巴瘤': ['disease'],
#              '同种免疫性新生儿血小板减少性紫癜': ['disease'],
#              '肛管、直肠、结肠狭窄': ['disease'],
#              '牙齿感觉过敏症': ['disease'],
#              '盆底腹膜疝': ['disease'],
#              '中枢神经系统白血病': ['disease'],
#              '系统性红斑狼疮': ['disease'],
#              '小儿原发性膀胱输尿管反流': ['disease'],
#              '变异性哮喘': ['disease'],
#              '变异性红斑角化病': ['disease'],
#              '小儿韦格纳肉芽肿': ['disease'],
#              '十二指肠憩室': ['disease'],
#              '膀胱颈挛缩': ['disease'],
#              '寰枢关节脱位': ['disease'],
#              'Whipple病': ['disease'],
#              '婴幼儿型内斜视': ['disease'],
#              '结膜炎': ['disease'],
#              '放射性甲状腺炎': ['disease'],
#              '迷路震荡': ['disease'],
#              '胃肠湿热': ['disease'],
#              '腹部肿瘤': ['disease'],
#              '颅底肿瘤': ['disease'],
#              '燥邪犯肺': ['disease'],
#              '妊娠合并哮喘': ['disease'],
#              '蛙粪霉病': ['disease'],
#              '乳痨': ['disease'],
#              '韦格纳肉芽肿性巩膜炎': ['disease'],
#              '先天性主动脉瓣上狭窄': ['disease'],
#              '泌尿系结石': ['disease'],
#              '胆囊类癌': ['disease'],
#              '阑尾寄生虫病': ['disease'],
#              '动静脉血管瘤': ['disease'],
#              '头皮撕脱伤': ['disease'],
#              '抗生素诱发的肠炎': ['disease'],
#              '小儿波-杰综合征': ['disease'],
#              '脐尿管瘘': ['disease'],
#              '外阴结核': ['disease'],
#              '低颅压综合征': ['disease'],
#              '遗传性抗凝血酶Ⅲ缺乏症': ['disease'],
#              '枕骨大孔脑膜瘤': ['disease'],
#              '结节性红斑': ['disease'],
#              '肺动静脉瘤': ['disease'],
#              '丛状血管瘤': ['disease'],
#              '少年性椎体骨软骨病': ['disease'],
#              '脾梗死': ['disease'],
#              '低钙血症和低镁血症': ['disease'],
#              '腺淋巴瘤': ['disease'],
#              '血管网织细胞瘤': ['disease'],
#              '咽喉烧伤及化学伤': ['disease'],
#              '原发性卵巢类癌综合征': ['disease'],
#              '急性单纯疱疹病毒性脑炎': ['disease'],
#              '阴茎痰核': ['disease'],
#              '腓总神经损害': ['disease'],
#              '寻常狼疮': ['disease'],
#              '老年人代谢性碱中毒': ['disease'],
#              '习惯性髌骨脱位': ['disease'],
#              '宫颈息肉': ['disease'],
#              '胃肠道癌': ['disease'],
#              '肝脏疾病所致贫血': ['disease'],
#              '心室扑动和心室颤动': ['disease'],
#              '息积': ['disease'],
#              '慢性单纯性鼻炎': ['disease'],
#              '肥气': ['disease'],
#              '胆囊-结肠肝曲粘连综合征': ['disease'],
#              '家族性载脂蛋白B100缺陷症': ['disease'],
#              '干血痨': ['disease'],
#              '细菌性心内膜炎': ['disease'],
#              '混合性厌氧菌感染': ['disease'],
#              '假性高血压': ['disease'],
#              '股动脉损伤': ['disease'],
#              '传染性脓疱病': ['disease'],
#              '多发脑梗死性痴呆': ['disease'],
#              '喉粘液囊肿': ['disease'],
#              '落叶型天疱疮': ['disease'],
#              '脑桥中央髓鞘溶解症': ['disease'],
#              '脉络膜缺损': ['disease'],
#              '软腭癌': ['disease'],
#              '皮下脂膜炎性T细胞淋巴瘤': ['disease'],
#              '小细胞低色素性贫血': ['disease'],
#              '暴泻': ['disease'],
#              '老年人肺栓塞': ['disease'],
#              '男性更年期综合症': ['disease'],
#              '脑膜瘤': ['disease'],
#              '急性胆囊炎': ['disease'],
#              '人格障碍': ['disease'],
#              '冠状动脉异位起源': ['disease'],
#              '异位ACTH综合征': ['disease'],
#              '沙雷菌肺炎': ['disease'],
#              '小儿急性髓样白血病': ['disease'],
#              '骨癌': ['disease'],
#              '慢性硬脑膜外血肿': ['disease'],
#              '胸廓出口综合征': ['disease'],
#              '妊娠痒疹': ['disease'],
#              '对苯二胺皮炎': ['disease'],
#              '急性阿米巴痢疾': ['disease'],
#              '强直性脊柱炎及其伴发的葡萄膜炎': ['disease'],
#              '继发性痛经': ['disease'],
#              '锡尘肺': ['disease'],
#              'α-贮存池病': ['disease'],
#              '小儿肝素-血小板减少-血栓形成综合征': ['disease'],
#              '恶性高血压': ['disease'],
#              '混合痔': ['disease'],
#              '外科皮脂腺囊肿': ['disease'],
#              '枕叶肿瘤': ['disease'],
#              '张力性气胸': ['disease'],
#              '心脏损伤': ['disease'],
#              '性病相关性胃肠道感染': ['disease'],
#              '椎动脉创伤性栓塞': ['disease'],
#              '小儿双唇综合征': ['disease'],
#              '非01霍乱弧菌肠炎': ['disease'],
#              '结节性脂肪坏死': ['disease'],
#              '乳头状腺瘤': ['disease'],
#              '小肠脂肪瘤': ['disease'],
#              '色素性痒疹': ['disease'],
#              '第三腰椎横突综合征': ['disease'],
#              '巨细胞病毒性葡萄膜炎': ['disease'],
#              '腹直肌自发性破裂': ['disease'],
#              '小棘毛壅病': ['disease'],
#              '疣状角化不良病': ['disease'],
#              '单纯疱疹病毒肺炎': ['disease'],
#              '脓疱性细菌疹': ['disease'],
#              '寒冷性荨麻疹': ['disease'],
#              '股骨干骨折': ['disease'],
#              '小儿分离性焦虑症': ['disease'],
#              '胆囊胆固醇沉着症': ['disease'],
#              '高血压性心脏病': ['disease'],
#              '甲状腺结核': ['disease'],
#              '小儿低钠血症': ['disease'],
#              '成人先天性髋关节脱位': ['disease'],
#              '外耳湿疹': ['disease'],
#              '小儿IgA肾病': ['disease'],
#              '妊娠期心脏病': ['disease'],
#              '胸壁骨肿瘤': ['disease'],
#              '自由生活阿米巴感染': ['disease'],
#              '老年人支气管哮喘': ['disease'],
#              '视网膜色素变性': ['disease'],
#              '硬化性脂肪肉芽肿': ['disease'],
#              '下颈椎不稳症': ['disease'],
#              'Marie-Bamberger综合征': ['disease'],
#              '外伤性腹膜后出血或血肿': ['disease'],
#              '血栓形成': ['disease'],
#              '弥漫性特发性骨肥厚': ['disease'],
#              '无功能性甲状旁腺囊肿': ['disease'],
#              '输卵管妊娠': ['disease'],
#              '乳腺炎': ['disease'],
#              '创伤性气胸': ['disease'],
#              '新生儿湿疹': ['disease'],
#              '老年人肺心病': ['disease'],
#              '胃炎': ['disease'],
#              '先天性鼻部皮样囊肿及瘘管': ['disease'],
#              '甲状腺功能减退伴发的精神障碍': ['disease'],
#              '多指畸形': ['disease'],
#              '妊娠合并偏头痛': ['disease'],
#              '肺痿': ['disease'],
#              '典型预激综合征': ['disease'],
#              '先天性喉蹼': ['disease'],
#              '皮脂腺癌': ['disease'],
#              '宫颈糜烂': ['disease'],
#              '隐匿阴茎': ['disease'],
#              '重复肾盂输尿管畸形': ['disease'],
#              '小儿成骨不全': ['disease'],
#              '色厥色脱': ['disease'],
#              '老年人厌氧菌性肺炎': ['disease'],
#              '血证': ['disease'],
#              '喉结核': ['disease'],
#              '阴道肿瘤': ['disease'],
#              '硬皮病': ['disease'],
#              '血管免疫母细胞性淋巴结病': ['disease'],
#              '脑蛛网膜炎': ['disease'],
#              '衣原体肺炎': ['disease'],
#              '血管炎': ['disease'],
#              '传导性耳聋': ['disease'],
#              '多发性一过性白点综合征': ['disease'],
#              '嗜酸细胞性胃肠炎': ['disease'],
#              '颞动脉炎': ['disease'],
#              '支气管扩张': ['disease'],
#              '急性高原病': ['disease'],
#              '肌膜炎': ['disease'],
#              '肌肉萎缩': ['disease'],
#              '下肢静脉血栓形成': ['disease'],
#              '躁狂抑郁症': ['disease'],
#              '面肌瘫痪': ['disease'],
#              '人为性皮炎': ['disease'],
#              '副乳乳腺癌': ['disease'],
#              '扁桃体周围脓肿': ['disease'],
#              '血管网状细胞瘤': ['disease'],
#              '阴道转移性肿瘤': ['disease'],
#              '委内瑞拉马脑炎': ['disease'],
#              '管状小汗腺癌': ['disease'],
#              '慢性淋巴细胞性白血病': ['disease'],
#              '脉络膜新生血管': ['disease'],
#              '汽油中毒': ['disease'],
#              '肾脓肿': ['disease'],
#              '血小板促凝活性异常': ['disease'],
#              '迷走神经损伤': ['disease'],
#              '广泛性焦虑障碍': ['disease'],
#              '阴道恶性苗勒管混合瘤': ['disease'],
#              'Q热肺炎': ['disease'],
#              '先天性厚甲症': ['disease'],
#              '小儿白血病': ['disease'],
#              '马蹄形肾': ['disease'],
#              '儿童顿咳': ['disease'],
#              '淋菌性尿道炎': ['disease'],
#              '颈部脊髓损伤': ['disease'],
#              '老年人低钙血症': ['disease'],
#              ...})

# %% [markdown]
# ### 构造AC自动机，加速实体提取

# %%
import ahocorasick

# 构造AC自动机，加速实体提取
def build_actree(wordlist):
    actree = ahocorasick.Automaton()
    for index, word in enumerate(wordlist):
        actree.add_word(word, (index, word))
    actree.make_automaton()
    return actree

region_tree = build_actree(list(dic.keys()))

# %%
'呼吸衰竭' in region_tree
# Out:
# True

# %%
region_tree.get('血常规')
# Out:
# (9570, '血常规')

# %% [markdown]
# ## 任务一：提取问题相关实体及其类别

# %%
question = '肺气肿和百日咳要做血常规吗？'

question_entity = []
for each in region_tree.iter(question):
    entity = each[1][1]
    question_entity.append(entity)
print(question_entity)
# Out:
# ['肺气肿', '百日咳', '血常规']

# %%
# stop_wds = []
# # 排除字符串子串
# for wd1 in region_words:
#     for wd2 in region_words:
#         if wd1 in wd2 and wd1!=wd2:
#             stop_wds.append(wd1)
# print(stop_wds)

# final_wds = [each for each in region_words if each not in stop_wds]
# final_wds

# %%
question_entity_dict = {each: dic[each] for each in question_entity}
question_entity_dict
# Out:
# {'肺气肿': ['disease'], '百日咳': ['disease'], '血常规': ['check']}

# %%
output = {}
output['args'] = question_entity_dict

# %% [markdown]
# ## 任务二：提取问题相关的待查询关系

# %%
# 问题中涉及的实体类别
types = []
for each in question_entity_dict.values():
    types.extend(each)
types
# Out:
# ['disease', 'disease', 'check']

# %%
# 不同提问意图的疑问词
symptom_qwds = ['症状', '表征', '现象', '症候', '表现']
cause_qwds = ['原因','成因', '为什么', '怎么会', '怎样才', '咋样才', '怎样会', '如何会', '为啥', '为何', '如何才会', '怎么才会', '会导致', '会造成']
acompany_qwds = ['并发症', '并发', '一起发生', '一并发生', '一起出现', '一并出现', '一同发生', '一同出现', '伴随发生', '伴随', '共现']
food_qwds = ['饮食', '饮用', '吃', '食', '伙食', '膳食', '喝', '菜' ,'忌口', '补品', '保健品', '食谱', '菜谱', '食用', '食物','补品']
drug_qwds = ['药', '药品', '用药', '胶囊', '口服液', '炎片']
prevent_qwds = ['预防', '防范', '抵制', '抵御', '防止','躲避','逃避','避开','免得','逃开','避开','避掉','躲开','躲掉','绕开',
                     '怎样才能不', '怎么才能不', '咋样才能不','咋才能不', '如何才能不',
                     '怎样才不', '怎么才不', '咋样才不','咋才不', '如何才不',
                     '怎样才可以不', '怎么才可以不', '咋样才可以不', '咋才可以不', '如何可以不',
                     '怎样才可不', '怎么才可不', '咋样才可不', '咋才可不', '如何可不']
lasttime_qwds = ['周期', '多久', '多长时间', '多少时间', '几天', '几年', '多少天', '多少小时', '几个小时', '多少年']
cureway_qwds = ['怎么治疗', '如何医治', '怎么医治', '怎么治', '怎么医', '如何治', '医治方式', '疗法', '咋治', '怎么办', '咋办', '咋治']
cureprob_qwds = ['多大概率能治好', '多大几率能治好', '治好希望大么', '几率', '几成', '比例', '可能性', '能治', '可治', '可以治', '可以医']
easyget_qwds = ['易感人群', '容易感染', '易发人群', '什么人', '哪些人', '感染', '染上', '得上']
check_qwds = ['检查', '检查项目', '查出', '检查', '测出', '试出']
belong_qwds = ['属于什么科', '属于', '什么科', '科室']
cure_qwds = ['治疗什么', '治啥', '治疗啥', '医治啥', '治愈啥', '主治啥', '主治什么', '有什么用', '有何用', '用处', '用途', '有什么好处', '有什么益处', '有何益处', '用来', '用来做啥', '用来作甚', '需要', '要']

# %%
def check_words(words, question):
    # 疑问词是否出现在提问中
    for word in words:
        if word in question:
            return True
    return False

# %%
question_types = []
# 疾病-症状
if check_words(symptom_qwds, question) and ('disease' in types):
    question_type = 'disease_symptom'
    question_types.append(question_type)
# 症状-疾病
if check_words(symptom_qwds, question) and ('symptom' in types):
    question_type = 'symptom_disease'
    question_types.append(question_type)
# 疾病-病因
if check_words(cause_qwds, question) and ('disease' in types):
    question_type = 'disease_cause'
    question_types.append(question_type)
# 疾病-并发症
if check_words(acompany_qwds, question) and ('disease' in types):
    question_type = 'disease_acompany'
    question_types.append(question_type)

# 疾病-可以吃/不可以吃
if check_words(food_qwds, question) and 'disease' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'disease_not_food'
    else:
        question_type = 'disease_do_food'
    question_types.append(question_type)
    
# 可以吃/不可以吃-疾病
if check_words(food_qwds+cure_qwds, question) and 'food' in types:
    deny_status = check_words(deny_words, question)
    if deny_status:
        question_type = 'food_not_disease'
    else:
        question_type = 'food_do_disease'
    question_types.append(question_type)
    
# 疾病-药物
if check_words(drug_qwds, question) and 'disease' in types:
    question_type = 'disease_drug'
    question_types.append(question_type)
    
# 药物-疾病
if check_words(cure_qwds, question) and 'drug' in types:
    question_type = 'drug_disease'
    question_types.append(question_type)
    
# 疾病-检查
if check_words(check_qwds, question) and 'disease' in types:
    question_type = 'disease_check'
    question_types.append(question_type)
    
# 检查-疾病
if check_words(check_qwds+cure_qwds, question) and 'check' in types:
    question_type = 'check_disease'
    question_types.append(question_type)
    
#　疾病-预防措施
if check_words(prevent_qwds, question) and 'disease' in types:
    question_type = 'disease_prevent'
    question_types.append(question_type)
    
# 疾病-疗程
if check_words(lasttime_qwds, question) and 'disease' in types:
    question_type = 'disease_lasttime'
    question_types.append(question_type)

# 疾病-疗法
if check_words(cureway_qwds, question) and 'disease' in types:
    question_type = 'disease_cureway'
    question_types.append(question_type)

# 疾病-治愈率
if check_words(cureprob_qwds, question) and 'disease' in types:
    question_type = 'disease_cureprob'
    question_types.append(question_type)

# 疾病-易感人群
if check_words(easyget_qwds, question) and 'disease' in types :
    question_type = 'disease_easyget'
    question_types.append(question_type)
    
# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'disease' in types:
    question_types = ['disease_desc']

# 若没有查到相关的外部查询信息，那么则将该疾病的描述信息返回
if question_types == [] and 'symptom' in types:
    question_types = ['symptom_disease']

# %%
question_types
# Out:
# ['check_disease']

# %%
# 将多个分类结果进行合并处理，组装成一个字典
output['question_types'] = question_types

args = output['args']

entity_dict = {}
for arg, types in args.items():
    for type in types:
        if type not in entity_dict:
            entity_dict[type] = [arg]
        else:
            entity_dict[type].append(arg)
entity_dict
# Out:
# {'disease': ['肺气肿', '百日咳'], 'check': ['血常规']}

# %%
output
# Out:
# {'args': {'肺气肿': ['disease'], '百日咳': ['disease'], '血常规': ['check']},
#  'question_types': ['check_disease']}

# %% [markdown]
# ### 生成cypher查询语句

# %%
# 不同的提问意图，对应不同关系的cypher查询语句
def sql_transfer(question_type, entities):
    if not entities:
        return []
    # 查询语句
    sql = []
    # 查询疾病的病因
    if question_type == 'disease_cause':
        sql = ["match (m:Disease) where m.name='{0}' return m.name, m.cause".format(i) for i in entities]
    # 查询疾病的预防措施
    elif question_type == 'disease_prevent':
        sql = ["match (m:Disease) where m.name='{0}' return m.name, m.prevent".format(i) for i in entities]
    # 查询疾病的疗程
    elif question_type == 'disease_lasttime':
        sql = ["MATCH (m:Disease) where m.name = '{0}' return m.name, m.cure_lasttime".format(i) for i in entities]

    # 查询疾病的治愈率
    elif question_type == 'disease_cureprob':
        sql = ["MATCH (m:Disease) where m.name = '{0}' return m.name, m.cured_prob".format(i) for i in entities]

    # 查询疾病的疗法
    elif question_type == 'disease_cureway':
        sql = ["MATCH (m:Disease) where m.name = '{0}' return m.name, m.cure_way".format(i) for i in entities]

    # 查询疾病的易感人群
    elif question_type == 'disease_easyget':
        sql = ["MATCH (m:Disease) where m.name = '{0}' return m.name, m.easy_get".format(i) for i in entities]

    # 查询疾病的描述
    elif question_type == 'disease_desc':
        sql = ["MATCH (m:Disease) where m.name = '{0}' return m.name, m.desc".format(i) for i in entities]

    # 查询疾病的症状
    elif question_type == 'disease_symptom':
        sql = ["MATCH (m:Disease)-[r:has_symptom]->(n:Symptom) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
    # 查询疾病的并发症
    elif question_type == 'disease_acompany':
        sql1 = ["MATCH (m:Disease)-[r:acompany_with]->(n:Disease) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql2 = ["MATCH (m:Disease)-[r:acompany_with]->(n:Disease) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql = sql1 + sql2

    # 查询疾病的忌口
    elif question_type == 'disease_not_food':
        sql = ["MATCH (m:Disease)-[r:no_eat]->(n:Food) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]

    # 查询疾病建议吃的东西
    elif question_type == 'disease_do_food':
        sql1 = ["MATCH (m:Disease)-[r:do_eat]->(n:Food) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql2 = ["MATCH (m:Disease)-[r:recommand_eat]->(n:Food) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql = sql1 + sql2

    # 已知忌口查疾病
    elif question_type == 'food_not_disease':
        sql = ["MATCH (m:Disease)-[r:no_eat]->(n:Food) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]

    # 已知推荐查疾病
    elif question_type == 'food_do_disease':
        sql1 = ["MATCH (m:Disease)-[r:do_eat]->(n:Food) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql2 = ["MATCH (m:Disease)-[r:recommand_eat]->(n:Food) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql = sql1 + sql2

    # 查询疾病常用药品－药品别名记得扩充
    elif question_type == 'disease_drug':
        sql1 = ["MATCH (m:Disease)-[r:common_drug]->(n:Drug) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql2 = ["MATCH (m:Disease)-[r:recommand_drug]->(n:Drug) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql = sql1 + sql2

    # 已知药品查询能够治疗的疾病
    elif question_type == 'drug_disease':
        sql1 = ["MATCH (m:Disease)-[r:common_drug]->(n:Drug) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql2 = ["MATCH (m:Disease)-[r:recommand_drug]->(n:Drug) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
        sql = sql1 + sql2
    # 查询疾病应该做的检查
    elif question_type == 'disease_check':
        sql = ["MATCH (m:Disease)-[r:need_check]->(n:Check) where m.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]

    # 已知检查查询疾病
    elif question_type == 'check_disease':
        sql = ["MATCH (m:Disease)-[r:need_check]->(n:Check) where n.name = '{0}' return m.name, r.name, n.name".format(i) for i in entities]
    
    return sql

# %%
sql_transfer('disease_cause', ['肺气肿', '百日咳'])
# Out:
# ["match (m:Disease) where m.name='肺气肿' return m.name, m.cause",
#  "match (m:Disease) where m.name='百日咳' return m.name, m.cause"]

# %%
sqls = []
for question_type in question_types:
    sql_ = {}
    sql_['question_type'] = question_type
    sql_['sql'] = sql_transfer(question_type, entity_dict.get(question_type.split('_')[0]))
    sqls.append(sql_)
sqls
# Out:
# [{'question_type': 'check_disease',
#   'sql': ["MATCH (m:Disease)-[r:need_check]->(n:Check) where n.name = '血常规' return m.name, r.name, n.name"]}]

# %% [markdown]
# ### 查询图数据库，生成回答

# %%
num_limit = 20

'''根据对应的qustion_type，调用相应的回复模板'''
def answer_prettify(question_type, answers):
    final_answer = []
    if not answers:
        return ''
    if question_type == 'disease_symptom':
        desc = [i['n.name'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}的症状包括：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'symptom_disease':
        desc = [i['m.name'] for i in answers]
        subject = answers[0]['n.name']
        final_answer = '症状{0}可能染上的疾病有：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_cause':
        desc = [i['m.cause'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}可能的成因有：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_prevent':
        desc = [i['m.prevent'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}的预防措施包括：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_lasttime':
        desc = [i['m.cure_lasttime'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}治疗可能持续的周期为：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_cureway':
        desc = [';'.join(i['m.cure_way']) for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}可以尝试如下治疗：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_cureprob':
        desc = [i['m.cured_prob'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}治愈的概率为（仅供参考）：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_easyget':
        desc = [i['m.easy_get'] for i in answers]
        subject = answers[0]['m.name']

        final_answer = '{0}的易感人群包括：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_desc':
        desc = [i['m.desc'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0},熟悉一下：{1}'.format(subject,  '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_acompany':
        desc1 = [i['n.name'] for i in answers]
        desc2 = [i['m.name'] for i in answers]
        subject = answers[0]['m.name']
        desc = [i for i in desc1 + desc2 if i != subject]
        final_answer = '{0}的症状包括：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_not_food':
        desc = [i['n.name'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}忌食的食物包括有：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_do_food':
        do_desc = [i['n.name'] for i in answers if i['r.name'] == '宜吃']
        recommand_desc = [i['n.name'] for i in answers if i['r.name'] == '推荐食谱']
        subject = answers[0]['m.name']
        final_answer = '{0}宜食的食物包括有：{1}\n推荐食谱包括有：{2}'.format(subject, ';'.join(list(set(do_desc))[:num_limit]), ';'.join(list(set(recommand_desc))[:self.num_limit]))

    elif question_type == 'food_not_disease':
        desc = [i['m.name'] for i in answers]
        subject = answers[0]['n.name']
        final_answer = '患有{0}的人最好不要吃{1}'.format('；'.join(list(set(desc))[:num_limit]), subject)

    elif question_type == 'food_do_disease':
        desc = [i['m.name'] for i in answers]
        subject = answers[0]['n.name']
        final_answer = '患有{0}的人建议多试试{1}'.format('；'.join(list(set(desc))[:num_limit]), subject)

    elif question_type == 'disease_drug':
        desc = [i['n.name'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}通常的使用的药品包括：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'drug_disease':
        desc = [i['m.name'] for i in answers]
        subject = answers[0]['n.name']
        final_answer = '{0}主治的疾病有{1},可以试试'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'disease_check':
        desc = [i['n.name'] for i in answers]
        subject = answers[0]['m.name']
        final_answer = '{0}通常可以通过以下方式检查出来：{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    elif question_type == 'check_disease':
        desc = [i['m.name'] for i in answers]
        subject = answers[0]['n.name']
        final_answer = '通常可以通过{0}检查出来的疾病有{1}'.format(subject, '；'.join(list(set(desc))[:num_limit]))

    return final_answer

# %%
sqls
# Out:
# [{'question_type': 'check_disease',
#   'sql': ["MATCH (m:Disease)-[r:need_check]->(n:Check) where n.name = '血常规' return m.name, r.name, n.name"]}]

# %%
for sql_ in sqls:
    question_type = sql_['question_type']
    queries = sql_['sql']
    answers = []
    for query in queries:
        res = graph.run(query).data()
        answers += res
answers
# Out:
# [{'m.name': '肺炎杆菌肺炎', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '肺炎球菌肺炎', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '放射性肺炎', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '二硫化碳中毒', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '大楼病综合征', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '大叶性肺炎', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '苯中毒', 'r.name': '诊断检查', 'n.name': '血常规'},
#  {'m.name': '百日咳', 'r.name': '诊断检查', 'n.name': '血常规'}]

# %%
final_answers = []

for sql_ in sqls:
    question_type = sql_['question_type']
    queries = sql_['sql']
    answers = []
    
    
    for query in queries: # 运行每一条cypher查询语句
        res = graph.run(query).data()
        answers += res
    final_answer = answer_prettify(question_type, answers)
    if final_answer:
        final_answers.append(final_answer)
        
final_answers
# Out:
# ['通常可以通过血常规检查出来的疾病有大楼病综合征；放射性肺炎；肺炎球菌肺炎；二硫化碳中毒；苯中毒；大叶性肺炎；百日咳；肺炎杆菌肺炎']
